# %%
import pandas as pd

# Load the Titanic dataset
# Replace 'titanic.csv' with the path to your dataset file
df = pd.read_csv('C:/Users/hp/Desktop/prodigy_titanic.csv')

# Display the first few rows of the dataset
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.info())

#  summary statistics
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the count of survivors and non-survivors
sns.countplot(x='Survived', data=df)
plt.title('Count of Survivors vs Non-Survivors')
plt.show()

# %%
# Plotting the distribution of Age
sns.histplot(df['Age'].dropna(), kde=True)
plt.title('Distribution of Age')
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plotting the distribution of Fare
sns.histplot(df['Fare'], kde=True)
plt.title('Distribution of Fare')
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plotting the count of passengers in each Pclass
sns.countplot(x='Pclass', data=df)
plt.title('Count of Passengers in Each Class')
plt.show()

# Plotting the count of male and female passengers
sns.countplot(x='Sex', data=df)
plt.title('Count of Male and Female Passengers')
plt.show()

# %%
# Plotting survival rate by Sex
sns.barplot(x='Sex', y='Survived', data=df)
plt.title('Survival Rate by Sex')
plt.show()

# %%
# Plotting survival rate by Pclass
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Passenger Class')
plt.show()

# %%
##DATA CLEANING

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# PassengerId         0
# Survived            0
# Pclass              0
# Name                0
# Age                 0
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# FamilySize          0
# IsAlone             0
# Sex_male            0
# Embarked_Q          0
# Embarked_S          0
# Title_Col           0
# Title_Countess      0
# Title_Don           0
# Title_Dr            0
# Title_Jonkheer      0
# Title_Lady          0
# Title_Major         0
# Title_Master        0
# Title_Miss          0
# Title_Mlle          0
# Title_Mme           0
# Title_Mr            0
# Title_Mrs           0
# Title_Ms            0
# Title_Rev           0
# Title_Sir           0
# dtype: int64

# %%
print (df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'FamilySize', 'IsAlone', 'Sex_male',
#        'Embarked_Q', 'Embarked_S', 'Title_Col', 'Title_Countess', 'Title_Don',
#        'Title_Dr', 'Title_Jonkheer', 'Title_Lady', 'Title_Major',
#        'Title_Master', 'Title_Miss', 'Title_Mlle', 'Title_Mme', 'Title_Mr',
#        'Title_Mrs', 'Title_Ms', 'Title_Rev', 'Title_Sir'],
#       dtype='object')

# %%
# Filling missing values in Age with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Filling missing values in Embarked with the most common value
df['Embarked_Q'].fillna(df['Embarked_Q'].mode()[0], inplace=True)
df['Embarked_S'].fillna(df['Embarked_S'].mode()[0], inplace=True)

# Filling missing values in Fare with the median
df['Fare'].fillna(df['Fare'].median(), inplace=True)

# Dropping the Cabin column due to many missing values
df.drop(columns='Cabin', inplace=True)

# %%
# Extract titles from names
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

df.drop(columns=['Name', 'Ticket'], inplace=True)

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['IsAlone'] = (df['FamilySize'] == 1).astype(int)

# %%
# Encode categorical variables
df = pd.get_dummies(df, columns=['Sex_male', 'Embarked_Q', 'Embarked_S', 'Title'], drop_first=True)
df = pd.get_dummies(df, columns=['Pclass'], drop_first=True)

# %%
df.drop(columns=['PassengerId'], inplace=True)

# %%
# Saving the cleaned dataset
df.to_csv('cleaned_titanic.csv', index=False)
